# %% [markdown]
# <a href="https://colab.research.google.com/github/SzymonNowakowski/Machine-Learning-2024/blob/master/Lab10-convolutional-neural-network-CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 10 - Convolutional Neural Network, CNN
#
# ### Author: Szymon Nowakowski

# %% [markdown]
# # Presentation on Convolutional Layers
# --------------------
#
# We shall start off by going through a [short presentation on convolusional layers](https://github.com/SzymonNowakowski/Machine-Learning-2024/blob/master/convolutional_layers.pdf). It is best to first download it and then go through it in a slide-show layout.

# %% [markdown]
# # Reading MNIST Dataset
# ----------------------------------

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

transform = torchvision.transforms.Compose(
    [ torchvision.transforms.ToTensor(), #Converts a PIL Image or numpy.ndarray (H x W x C) in the range [0, 255] to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0]
      torchvision.transforms.Normalize((0.1307), (0.3081))])

trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=2048,
                                          shuffle=True)   #we do shuffle it to give more randomizations to training epochs

testset = torchvision.datasets.MNIST(root='./data',
                                     train=False,
                                     download=True,
                                     transform=transform)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=1,
                                         shuffle=False)

# %% [markdown]
# # Tensor Sizes
# -------------------
#
# Recall:
# - Batched labels are of order one. The first (and only) index is a sample index within a batch.
# - Image batches have order 4. The first order is a batch order, but a second order has dimensionality of 1 and thus it can be indexed by 0 only.
#   - This index represents a Channel number inserted here by `ToTensor()` transformation, always 0.
#   - This singleton order should be retained because we want to use convolutional layers, which explicitly require this order. For RGB images we have 3 channels, for B&W images we have only one channel.

# %% [markdown]
# # CNN Definition
# -----------------

# %% [markdown]
# ## Task
#
# Your job now is to code the definition of the LeNet5 neural network. You can find the definition [here](https://en.wikipedia.org/wiki/LeNet#/media/File:Comparison_image_neural_networks.svg).

# %%
import torch.nn as nn
import torch.nn.functional as F

class LeNet5(torch.nn.Module):
    def __init__(self):
        super().__init__()

        # TODO: add missing layers
        self.relu = torch.nn.ReLU()
        self.avgpool = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, padding=2, padding_mode='replicate')
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0)
        self.conv3 = torch.nn.Conv2d(in_channels=16, out_channels=120, kernel_size=5, padding=0)
        
        self.linear1 = torch.nn.Linear(120, 84)
        self.linear2 = torch.nn.Linear(84, 10)
        self.dropout = torch.nn.Dropout(0.05)

    def forward(self, x):

        # TODO: add missing processing
        # Convolutional part
        x = self.conv1(x)
        x = self.relu(x)
        x = self.avgpool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.avgpool(x)
        x = self.conv3(x)
        x = self.relu(x)
        
        # Linear part
        x = x.squeeze(-1).squeeze(-1)
        
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        # x = self.relu(x)
        
        x = self.dropout(x)
        return x

# %% [markdown]
# # Training Loop
# ----------------------

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Working on {device}")

net = LeNet5().to(device)
optimizer = torch.optim.Adam(net.parameters(), 0.001)   #initial and fixed learning rate of 0.001.

net.train()    #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing traning
for epoch in range(16):  #  an epoch is a training run through the whole data set

    for batch, data in enumerate(trainloader):
        batch_inputs, batch_labels = data

        batch_inputs = batch_inputs.to(device)  #explicitly moving the data to the target device
        batch_labels = batch_labels.to(device)

        optimizer.zero_grad()

        batch_outputs = net(batch_inputs)   #this line calls the forward(self, x) method of the LeNet5 object. Please note,
                                            # the nonlinear activation after the last layer is NOT applied
        loss = torch.nn.functional.cross_entropy(batch_outputs, batch_labels, reduction = "mean") #instead, nonlinear softmax is applied internally in THIS loss function
        print("epoch:", epoch, "batch:", batch, "current batch loss:", loss.item())
        loss.backward()       #this computes gradients as we have seen in previous workshops
        optimizer.step()      #but this line in fact updates our neural network.
                                ####You can experiment - comment this line and check, that the loss DOE
# Out:
# Working on cuda
# epoch: 0 batch: 0 current batch loss: 2.3024744987487793
# epoch: 0 batch: 1 current batch loss: 2.289837598800659
# epoch: 0 batch: 2 current batch loss: 2.280076742172241
# epoch: 0 batch: 3 current batch loss: 2.2659847736358643
# epoch: 0 batch: 4 current batch loss: 2.2495651245117188
# epoch: 0 batch: 5 current batch loss: 2.226581335067749
# epoch: 0 batch: 6 current batch loss: 2.195929765701294
# epoch: 0 batch: 7 current batch loss: 2.164442300796509
# epoch: 0 batch: 8 current batch loss: 2.124182939529419
# epoch: 0 batch: 9 current batch loss: 2.074089765548706
# epoch: 0 batch: 10 current batch loss: 2.022758960723877
# epoch: 0 batch: 11 current batch loss: 1.95377516746521
# epoch: 0 batch: 12 current batch loss: 1.890544056892395
# epoch: 0 batch: 13 current batch loss: 1.7866766452789307
# epoch: 0 batch: 14 current batch loss: 1.7071292400360107
# epoch: 0 batch: 15 current batch loss: 1.6016596555709839
# epoch: 0 batch: 16 current batch loss: 1.494877576828003
# epoch: 0 batch: 17 current batch loss: 1.3971264362335205
# epoch: 0 batch: 18 current batch loss: 1.2923978567123413
# epoch: 0 batch: 19 current batch loss: 1.2216380834579468
# epoch: 0 batch: 20 current batch loss: 1.1378170251846313
# epoch: 0 batch: 21 current batch loss: 1.0708118677139282
# epoch: 0 batch: 22 current batch loss: 0.9971827268600464
# epoch: 0 batch: 23 current batch loss: 0.9452155232429504
# epoch: 0 batch: 24 current batch loss: 0.8679308891296387
# epoch: 0 batch: 25 current batch loss: 0.838255763053894
# epoch: 0 batch: 26 current batch loss: 0.8039301037788391
# epoch: 0 batch: 27 current batch loss: 0.7737196683883667
# epoch: 0 batch: 28 current batch loss: 0.7437263131141663
# epoch: 0 batch: 29 current batch loss: 0.7290682792663574
# epoch: 1 batch: 0 current batch loss: 0.7304096817970276
# epoch: 1 batch: 1 current batch loss: 0.7118716239929199
# epoch: 1 batch: 2 current batch loss: 0.6869223713874817
# epoch: 1 batch: 3 current batch loss: 0.6449358463287354
# epoch: 1 batch: 4 current batch loss: 0.6813174486160278
# epoch: 1 batch: 5 current batch loss: 0.6167306303977966
# epoch: 1 batch: 6 current batch loss: 0.6607343554496765
# epoch: 1 batch: 7 current batch loss: 0.6916733384132385
# epoch: 1 batch: 8 current batch loss: 0.6174836754798889
# epoch: 1 batch: 9 current batch loss: 0.5673741698265076
# epoch: 1 batch: 10 current batch loss: 0.6047723293304443
# epoch: 1 batch: 11 current batch loss: 0.5688194632530212
# epoch: 1 batch: 12 current batch loss: 0.5695345401763916
# epoch: 1 batch: 13 current batch loss: 0.6088483333587646
# epoch: 1 batch: 14 current batch loss: 0.5786489248275757
# epoch: 1 batch: 15 current batch loss: 0.523678183555603
# epoch: 1 batch: 16 current batch loss: 0.5164881944656372
# epoch: 1 batch: 17 current batch loss: 0.5214748382568359
# epoch: 1 batch: 18 current batch loss: 0.5486359596252441
# epoch: 1 batch: 19 current batch loss: 0.5175384879112244
# epoch: 1 batch: 20 current batch loss: 0.5263436436653137
# epoch: 1 batch: 21 current batch loss: 0.49657705426216125
# epoch: 1 batch: 22 current batch loss: 0.5020357370376587
# epoch: 1 batch: 23 current batch loss: 0.49419769644737244
# epoch: 1 batch: 24 current batch loss: 0.4446713328361511
# epoch: 1 batch: 25 current batch loss: 0.46158671379089355
# epoch: 1 batch: 26 current batch loss: 0.4645218849182129
# epoch: 1 batch: 27 current batch loss: 0.4871564507484436
# epoch: 1 batch: 28 current batch loss: 0.46492451429367065
# epoch: 1 batch: 29 current batch loss: 0.42120492458343506
# epoch: 2 batch: 0 current batch loss: 0.44772467017173767
# epoch: 2 batch: 1 current batch loss: 0.44139546155929565
# epoch: 2 batch: 2 current batch loss: 0.4553367495536804
# epoch: 2 batch: 3 current batch loss: 0.4466134011745453
# epoch: 2 batch: 4 current batch loss: 0.4016147553920746
# epoch: 2 batch: 5 current batch loss: 0.3857879042625427
# epoch: 2 batch: 6 current batch loss: 0.4520712196826935
# epoch: 2 batch: 7 current batch loss: 0.4418220520019531
# epoch: 2 batch: 8 current batch loss: 0.4541727602481842
# epoch: 2 batch: 9 current batch loss: 0.4662777781486511
# epoch: 2 batch: 10 current batch loss: 0.40868839621543884
# epoch: 2 batch: 11 current batch loss: 0.40207597613334656
# epoch: 2 batch: 12 current batch loss: 0.4728653132915497
# epoch: 2 batch: 13 current batch loss: 0.4385223090648651
# epoch: 2 batch: 14 current batch loss: 0.4197552502155304
# epoch: 2 batch: 15 current batch loss: 0.43963444232940674
# epoch: 2 batch: 16 current batch loss: 0.3920406699180603
# epoch: 2 batch: 17 current batch loss: 0.3818036913871765
# epoch: 2 batch: 18 current batch loss: 0.41142043471336365
# epoch: 2 batch: 19 current batch loss: 0.3983669877052307
# epoch: 2 batch: 20 current batch loss: 0.3714108467102051
# epoch: 2 batch: 21 current batch loss: 0.3986980617046356
# epoch: 2 batch: 22 current batch loss: 0.37543419003486633
# epoch: 2 batch: 23 current batch loss: 0.3667130470275879
# epoch: 2 batch: 24 current batch loss: 0.37575244903564453
# epoch: 2 batch: 25 current batch loss: 0.3964422047138214
# epoch: 2 batch: 26 current batch loss: 0.3571663796901703
# epoch: 2 batch: 27 current batch loss: 0.3649483621120453
# epoch: 2 batch: 28 current batch loss: 0.38484618067741394
# epoch: 2 batch: 29 current batch loss: 0.382002592086792
# epoch: 3 batch: 0 current batch loss: 0.3378686010837555
# epoch: 3 batch: 1 current batch loss: 0.3384093642234802
# epoch: 3 batch: 2 current batch loss: 0.36892250180244446
# epoch: 3 batch: 3 current batch loss: 0.3485129773616791
# epoch: 3 batch: 4 current batch loss: 0.36293867230415344
# epoch: 3 batch: 5 current batch loss: 0.3652710020542145
# epoch: 3 batch: 6 current batch loss: 0.3638424873352051
# epoch: 3 batch: 7 current batch loss: 0.36535897850990295
# epoch: 3 batch: 8 current batch loss: 0.3849179446697235
# epoch: 3 batch: 9 current batch loss: 0.3473878502845764
# epoch: 3 batch: 10 current batch loss: 0.34915727376937866
# epoch: 3 batch: 11 current batch loss: 0.3639972507953644
# epoch: 3 batch: 12 current batch loss: 0.3353005051612854
# epoch: 3 batch: 13 current batch loss: 0.34923112392425537
# epoch: 3 batch: 14 current batch loss: 0.3347546458244324
# epoch: 3 batch: 15 current batch loss: 0.34649115800857544
# epoch: 3 batch: 16 current batch loss: 0.361000120639801
# epoch: 3 batch: 17 current batch loss: 0.3402745723724365
# epoch: 3 batch: 18 current batch loss: 0.3117561340332031
# epoch: 3 batch: 19 current batch loss: 0.3137125074863434
# epoch: 3 batch: 20 current batch loss: 0.31488531827926636
# epoch: 3 batch: 21 current batch loss: 0.3631242513656616
# epoch: 3 batch: 22 current batch loss: 0.3428806662559509
# epoch: 3 batch: 23 current batch loss: 0.3446131646633148
# epoch: 3 batch: 24 current batch loss: 0.28402790427207947
# epoch: 3 batch: 25 current batch loss: 0.3407950699329376
# epoch: 3 batch: 26 current batch loss: 0.32923412322998047
# epoch: 3 batch: 27 current batch loss: 0.29740116000175476
# epoch: 3 batch: 28 current batch loss: 0.2980445921421051
# epoch: 3 batch: 29 current batch loss: 0.3441848158836365
# epoch: 4 batch: 0 current batch loss: 0.294757604598999
# epoch: 4 batch: 1 current batch loss: 0.32349297404289246
# epoch: 4 batch: 2 current batch loss: 0.30948370695114136
# epoch: 4 batch: 3 current batch loss: 0.3268289864063263
# epoch: 4 batch: 4 current batch loss: 0.33714810013771057
# epoch: 4 batch: 5 current batch loss: 0.3033689558506012
# epoch: 4 batch: 6 current batch loss: 0.30445829033851624
# epoch: 4 batch: 7 current batch loss: 0.3302846848964691
# epoch: 4 batch: 8 current batch loss: 0.30902329087257385
# epoch: 4 batch: 9 current batch loss: 0.29462018609046936
# epoch: 4 batch: 10 current batch loss: 0.3045320212841034
# epoch: 4 batch: 11 current batch loss: 0.2981835901737213
# epoch: 4 batch: 12 current batch loss: 0.2739846408367157
# epoch: 4 batch: 13 current batch loss: 0.2884671986103058
# epoch: 4 batch: 14 current batch loss: 0.27304336428642273
# epoch: 4 batch: 15 current batch loss: 0.2744891345500946
# epoch: 4 batch: 16 current batch loss: 0.30230897665023804
# epoch: 4 batch: 17 current batch loss: 0.2772165536880493
# epoch: 4 batch: 18 current batch loss: 0.29798945784568787
# epoch: 4 batch: 19 current batch loss: 0.2718135118484497
# epoch: 4 batch: 20 current batch loss: 0.30660146474838257
# epoch: 4 batch: 21 current batch loss: 0.2738116979598999
# epoch: 4 batch: 22 current batch loss: 0.3026732802391052
# epoch: 4 batch: 23 current batch loss: 0.274028480052948
# epoch: 4 batch: 24 current batch loss: 0.2678898572921753
# epoch: 4 batch: 25 current batch loss: 0.2598007917404175
# epoch: 4 batch: 26 current batch loss: 0.2952673137187958
# epoch: 4 batch: 27 current batch loss: 0.2752012312412262
# epoch: 4 batch: 28 current batch loss: 0.23715710639953613
# epoch: 4 batch: 29 current batch loss: 0.3047390878200531
# epoch: 5 batch: 0 current batch loss: 0.26277583837509155
# epoch: 5 batch: 1 current batch loss: 0.2445959746837616
# epoch: 5 batch: 2 current batch loss: 0.25368255376815796
# epoch: 5 batch: 3 current batch loss: 0.2856599986553192
# epoch: 5 batch: 4 current batch loss: 0.25713881850242615
# epoch: 5 batch: 5 current batch loss: 0.24395859241485596
# epoch: 5 batch: 6 current batch loss: 0.2539156377315521
# epoch: 5 batch: 7 current batch loss: 0.25874510407447815
# epoch: 5 batch: 8 current batch loss: 0.25931352376937866
# epoch: 5 batch: 9 current batch loss: 0.2239697277545929
# epoch: 5 batch: 10 current batch loss: 0.24152900278568268
# epoch: 5 batch: 11 current batch loss: 0.2330969274044037
# epoch: 5 batch: 12 current batch loss: 0.26336991786956787
# epoch: 5 batch: 13 current batch loss: 0.2565174400806427
# epoch: 5 batch: 14 current batch loss: 0.27147015929222107
# epoch: 5 batch: 15 current batch loss: 0.25010883808135986
# epoch: 5 batch: 16 current batch loss: 0.2444687783718109
# epoch: 5 batch: 17 current batch loss: 0.2697053849697113
# epoch: 5 batch: 18 current batch loss: 0.24288128316402435
# epoch: 5 batch: 19 current batch loss: 0.25211599469184875
# epoch: 5 batch: 20 current batch loss: 0.23784688115119934
# epoch: 5 batch: 21 current batch loss: 0.26779723167419434
# epoch: 5 batch: 22 current batch loss: 0.26966604590415955
# epoch: 5 batch: 23 current batch loss: 0.21856556832790375
# epoch: 5 batch: 24 current batch loss: 0.2397809773683548
# epoch: 5 batch: 25 current batch loss: 0.22500549256801605
# epoch: 5 batch: 26 current batch loss: 0.26423314213752747
# epoch: 5 batch: 27 current batch loss: 0.22534868121147156
# epoch: 5 batch: 28 current batch loss: 0.24806737899780273
# epoch: 5 batch: 29 current batch loss: 0.2218942940235138
# epoch: 6 batch: 0 current batch loss: 0.20810897648334503
# epoch: 6 batch: 1 current batch loss: 0.2131120264530182
# epoch: 6 batch: 2 current batch loss: 0.24723707139492035
# epoch: 6 batch: 3 current batch loss: 0.2351028174161911
# epoch: 6 batch: 4 current batch loss: 0.2280578315258026
# epoch: 6 batch: 5 current batch loss: 0.230032816529274
# epoch: 6 batch: 6 current batch loss: 0.25672245025634766
# epoch: 6 batch: 7 current batch loss: 0.23817500472068787
# epoch: 6 batch: 8 current batch loss: 0.24294541776180267
# epoch: 6 batch: 9 current batch loss: 0.2231927067041397
# epoch: 6 batch: 10 current batch loss: 0.243062824010849
# epoch: 6 batch: 11 current batch loss: 0.21478211879730225
# epoch: 6 batch: 12 current batch loss: 0.22168318927288055
# epoch: 6 batch: 13 current batch loss: 0.23756356537342072
# epoch: 6 batch: 14 current batch loss: 0.19999930262565613
# epoch: 6 batch: 15 current batch loss: 0.2064511626958847
# epoch: 6 batch: 16 current batch loss: 0.22718879580497742
# epoch: 6 batch: 17 current batch loss: 0.20111149549484253
# epoch: 6 batch: 18 current batch loss: 0.2124280035495758
# epoch: 6 batch: 19 current batch loss: 0.20574288070201874
# epoch: 6 batch: 20 current batch loss: 0.22747814655303955
# epoch: 6 batch: 21 current batch loss: 0.21953269839286804
# epoch: 6 batch: 22 current batch loss: 0.22029753029346466
# epoch: 6 batch: 23 current batch loss: 0.21174795925617218
# epoch: 6 batch: 24 current batch loss: 0.18761402368545532
# epoch: 6 batch: 25 current batch loss: 0.21240757405757904
# epoch: 6 batch: 26 current batch loss: 0.2109510600566864
# epoch: 6 batch: 27 current batch loss: 0.21954506635665894
# epoch: 6 batch: 28 current batch loss: 0.21548688411712646
# epoch: 6 batch: 29 current batch loss: 0.23850011825561523
# epoch: 7 batch: 0 current batch loss: 0.19834567606449127
# epoch: 7 batch: 1 current batch loss: 0.24097849428653717
# epoch: 7 batch: 2 current batch loss: 0.21318954229354858
# epoch: 7 batch: 3 current batch loss: 0.1907610148191452
# epoch: 7 batch: 4 current batch loss: 0.1993391066789627
# epoch: 7 batch: 5 current batch loss: 0.2100800722837448
# epoch: 7 batch: 6 current batch loss: 0.21204401552677155
# epoch: 7 batch: 7 current batch loss: 0.1767028272151947
# epoch: 7 batch: 8 current batch loss: 0.20161499083042145
# epoch: 7 batch: 9 current batch loss: 0.20739690959453583
# epoch: 7 batch: 10 current batch loss: 0.19921836256980896
# epoch: 7 batch: 11 current batch loss: 0.16683648526668549
# epoch: 7 batch: 12 current batch loss: 0.19385412335395813
# epoch: 7 batch: 13 current batch loss: 0.2062663584947586
# epoch: 7 batch: 14 current batch loss: 0.1887323558330536
# epoch: 7 batch: 15 current batch loss: 0.1855984777212143
# epoch: 7 batch: 16 current batch loss: 0.17295923829078674
# epoch: 7 batch: 17 current batch loss: 0.19038161635398865
# epoch: 7 batch: 18 current batch loss: 0.19092904031276703
# epoch: 7 batch: 19 current batch loss: 0.18589499592781067
# epoch: 7 batch: 20 current batch loss: 0.18868093192577362
# epoch: 7 batch: 21 current batch loss: 0.19720999896526337
# epoch: 7 batch: 22 current batch loss: 0.17672020196914673
# epoch: 7 batch: 23 current batch loss: 0.20299027860164642
# epoch: 7 batch: 24 current batch loss: 0.20964564383029938
# epoch: 7 batch: 25 current batch loss: 0.1797429621219635
# epoch: 7 batch: 26 current batch loss: 0.20957443118095398
# epoch: 7 batch: 27 current batch loss: 0.18691913783550262
# epoch: 7 batch: 28 current batch loss: 0.16725407540798187
# epoch: 7 batch: 29 current batch loss: 0.1429675817489624
# epoch: 8 batch: 0 current batch loss: 0.16799210011959076
# epoch: 8 batch: 1 current batch loss: 0.19428052008152008
# epoch: 8 batch: 2 current batch loss: 0.15795759856700897
# epoch: 8 batch: 3 current batch loss: 0.1835823953151703
# epoch: 8 batch: 4 current batch loss: 0.18245162069797516
# epoch: 8 batch: 5 current batch loss: 0.18253105878829956
# epoch: 8 batch: 6 current batch loss: 0.20939438045024872
# epoch: 8 batch: 7 current batch loss: 0.1725531965494156
# epoch: 8 batch: 8 current batch loss: 0.16715583205223083
# epoch: 8 batch: 9 current batch loss: 0.17657974362373352
# epoch: 8 batch: 10 current batch loss: 0.1749667227268219
# epoch: 8 batch: 11 current batch loss: 0.18486909568309784
# epoch: 8 batch: 12 current batch loss: 0.17537368834018707
# epoch: 8 batch: 13 current batch loss: 0.15791957080364227
# epoch: 8 batch: 14 current batch loss: 0.16556140780448914
# epoch: 8 batch: 15 current batch loss: 0.1848912090063095
# epoch: 8 batch: 16 current batch loss: 0.17912545800209045
# epoch: 8 batch: 17 current batch loss: 0.19005130231380463
# epoch: 8 batch: 18 current batch loss: 0.15315695106983185
# epoch: 8 batch: 19 current batch loss: 0.182786226272583
# epoch: 8 batch: 20 current batch loss: 0.20186050236225128
# epoch: 8 batch: 21 current batch loss: 0.19119349122047424
# epoch: 8 batch: 22 current batch loss: 0.19728729128837585
# epoch: 8 batch: 23 current batch loss: 0.1914271116256714
# epoch: 8 batch: 24 current batch loss: 0.17049317061901093
# epoch: 8 batch: 25 current batch loss: 0.15702573955059052
# epoch: 8 batch: 26 current batch loss: 0.151713028550148
# epoch: 8 batch: 27 current batch loss: 0.16619524359703064
# epoch: 8 batch: 28 current batch loss: 0.15324363112449646
# epoch: 8 batch: 29 current batch loss: 0.1696278601884842
# epoch: 9 batch: 0 current batch loss: 0.17885272204875946
# epoch: 9 batch: 1 current batch loss: 0.1612766981124878
# epoch: 9 batch: 2 current batch loss: 0.16578681766986847
# epoch: 9 batch: 3 current batch loss: 0.1561467945575714
# epoch: 9 batch: 4 current batch loss: 0.18318824470043182
# epoch: 9 batch: 5 current batch loss: 0.17253677546977997
# epoch: 9 batch: 6 current batch loss: 0.13625580072402954
# epoch: 9 batch: 7 current batch loss: 0.15242454409599304
# epoch: 9 batch: 8 current batch loss: 0.1696176379919052
# epoch: 9 batch: 9 current batch loss: 0.1591147929430008
# epoch: 9 batch: 10 current batch loss: 0.14439448714256287
# epoch: 9 batch: 11 current batch loss: 0.15620146691799164
# epoch: 9 batch: 12 current batch loss: 0.15883702039718628
# epoch: 9 batch: 13 current batch loss: 0.16063766181468964
# epoch: 9 batch: 14 current batch loss: 0.15959298610687256
# epoch: 9 batch: 15 current batch loss: 0.1577627956867218
# epoch: 9 batch: 16 current batch loss: 0.14618472754955292
# epoch: 9 batch: 17 current batch loss: 0.14248651266098022
# epoch: 9 batch: 18 current batch loss: 0.14335978031158447
# epoch: 9 batch: 19 current batch loss: 0.1527750939130783
# epoch: 9 batch: 20 current batch loss: 0.16845008730888367
# epoch: 9 batch: 21 current batch loss: 0.15549305081367493
# epoch: 9 batch: 22 current batch loss: 0.15275603532791138
# epoch: 9 batch: 23 current batch loss: 0.15078207850456238
# epoch: 9 batch: 24 current batch loss: 0.1494220346212387
# epoch: 9 batch: 25 current batch loss: 0.15688705444335938
# epoch: 9 batch: 26 current batch loss: 0.14148381352424622
# epoch: 9 batch: 27 current batch loss: 0.16991417109966278
# epoch: 9 batch: 28 current batch loss: 0.16743946075439453
# epoch: 9 batch: 29 current batch loss: 0.17409901320934296
# epoch: 10 batch: 0 current batch loss: 0.17357602715492249
# epoch: 10 batch: 1 current batch loss: 0.14983433485031128
# epoch: 10 batch: 2 current batch loss: 0.15299712121486664
# epoch: 10 batch: 3 current batch loss: 0.16004011034965515
# epoch: 10 batch: 4 current batch loss: 0.16786542534828186
# epoch: 10 batch: 5 current batch loss: 0.13638298213481903
# epoch: 10 batch: 6 current batch loss: 0.12398945540189743
# epoch: 10 batch: 7 current batch loss: 0.14662225544452667
# epoch: 10 batch: 8 current batch loss: 0.15682773292064667
# epoch: 10 batch: 9 current batch loss: 0.1342678666114807
# epoch: 10 batch: 10 current batch loss: 0.15009522438049316
# epoch: 10 batch: 11 current batch loss: 0.15929089486598969
# epoch: 10 batch: 12 current batch loss: 0.12491932511329651
# epoch: 10 batch: 13 current batch loss: 0.13900785148143768
# epoch: 10 batch: 14 current batch loss: 0.1583179086446762
# epoch: 10 batch: 15 current batch loss: 0.13406015932559967
# epoch: 10 batch: 16 current batch loss: 0.14199328422546387
# epoch: 10 batch: 17 current batch loss: 0.1359259933233261
# epoch: 10 batch: 18 current batch loss: 0.13338376581668854
# epoch: 10 batch: 19 current batch loss: 0.1595967561006546
# epoch: 10 batch: 20 current batch loss: 0.14096488058567047
# epoch: 10 batch: 21 current batch loss: 0.14266058802604675
# epoch: 10 batch: 22 current batch loss: 0.11897608637809753
# epoch: 10 batch: 23 current batch loss: 0.1381906121969223
# epoch: 10 batch: 24 current batch loss: 0.13480468094348907
# epoch: 10 batch: 25 current batch loss: 0.11995527893304825
# epoch: 10 batch: 26 current batch loss: 0.12130754441022873
# epoch: 10 batch: 27 current batch loss: 0.12451140582561493
# epoch: 10 batch: 28 current batch loss: 0.1374293565750122
# epoch: 10 batch: 29 current batch loss: 0.18507543206214905
# epoch: 11 batch: 0 current batch loss: 0.12671779096126556
# epoch: 11 batch: 1 current batch loss: 0.11962668597698212
# epoch: 11 batch: 2 current batch loss: 0.15048114955425262
# epoch: 11 batch: 3 current batch loss: 0.13866591453552246
# epoch: 11 batch: 4 current batch loss: 0.12508082389831543
# epoch: 11 batch: 5 current batch loss: 0.15170015394687653
# epoch: 11 batch: 6 current batch loss: 0.14205718040466309
# epoch: 11 batch: 7 current batch loss: 0.12772434949874878
# epoch: 11 batch: 8 current batch loss: 0.13534826040267944
# epoch: 11 batch: 9 current batch loss: 0.13516369462013245
# epoch: 11 batch: 10 current batch loss: 0.13332189619541168
# epoch: 11 batch: 11 current batch loss: 0.11707084625959396
# epoch: 11 batch: 12 current batch loss: 0.14564017951488495
# epoch: 11 batch: 13 current batch loss: 0.13340656459331512
# epoch: 11 batch: 14 current batch loss: 0.13396157324314117
# epoch: 11 batch: 15 current batch loss: 0.1230318620800972
# epoch: 11 batch: 16 current batch loss: 0.11783460527658463
# epoch: 11 batch: 17 current batch loss: 0.1326785683631897
# epoch: 11 batch: 18 current batch loss: 0.12507140636444092
# epoch: 11 batch: 19 current batch loss: 0.10996649414300919
# epoch: 11 batch: 20 current batch loss: 0.12782053649425507
# epoch: 11 batch: 21 current batch loss: 0.11911527067422867
# epoch: 11 batch: 22 current batch loss: 0.14458388090133667
# epoch: 11 batch: 23 current batch loss: 0.13391585648059845
# epoch: 11 batch: 24 current batch loss: 0.13081057369709015
# epoch: 11 batch: 25 current batch loss: 0.12768049538135529
# epoch: 11 batch: 26 current batch loss: 0.13442380726337433
# epoch: 11 batch: 27 current batch loss: 0.15130189061164856
# epoch: 11 batch: 28 current batch loss: 0.12044686079025269
# epoch: 11 batch: 29 current batch loss: 0.14036579430103302
# epoch: 12 batch: 0 current batch loss: 0.1267118901014328
# epoch: 12 batch: 1 current batch loss: 0.11722470819950104
# epoch: 12 batch: 2 current batch loss: 0.09439990669488907
# epoch: 12 batch: 3 current batch loss: 0.13082273304462433
# epoch: 12 batch: 4 current batch loss: 0.11529216915369034
# epoch: 12 batch: 5 current batch loss: 0.12344402819871902
# epoch: 12 batch: 6 current batch loss: 0.13213522732257843
# epoch: 12 batch: 7 current batch loss: 0.12796464562416077
# epoch: 12 batch: 8 current batch loss: 0.14177146553993225
# epoch: 12 batch: 9 current batch loss: 0.11665518581867218
# epoch: 12 batch: 10 current batch loss: 0.13099724054336548
# epoch: 12 batch: 11 current batch loss: 0.13459567725658417
# epoch: 12 batch: 12 current batch loss: 0.11155189573764801
# epoch: 12 batch: 13 current batch loss: 0.14926165342330933
# epoch: 12 batch: 14 current batch loss: 0.13227970898151398
# epoch: 12 batch: 15 current batch loss: 0.12143225222826004
# epoch: 12 batch: 16 current batch loss: 0.1368665248155594
# epoch: 12 batch: 17 current batch loss: 0.13142138719558716
# epoch: 12 batch: 18 current batch loss: 0.12205331772565842
# epoch: 12 batch: 19 current batch loss: 0.1111101359128952
# epoch: 12 batch: 20 current batch loss: 0.11888256669044495
# epoch: 12 batch: 21 current batch loss: 0.128935769200325
# epoch: 12 batch: 22 current batch loss: 0.1059935986995697
# epoch: 12 batch: 23 current batch loss: 0.1354479193687439
# epoch: 12 batch: 24 current batch loss: 0.11698003858327866
# epoch: 12 batch: 25 current batch loss: 0.10206998139619827
# epoch: 12 batch: 26 current batch loss: 0.11646264791488647
# epoch: 12 batch: 27 current batch loss: 0.1290295124053955
# epoch: 12 batch: 28 current batch loss: 0.12137823551893234
# epoch: 12 batch: 29 current batch loss: 0.1270875632762909
# epoch: 13 batch: 0 current batch loss: 0.11677246540784836
# epoch: 13 batch: 1 current batch loss: 0.10941584408283234
# epoch: 13 batch: 2 current batch loss: 0.11191622912883759
# epoch: 13 batch: 3 current batch loss: 0.11297871172428131
# epoch: 13 batch: 4 current batch loss: 0.1204213872551918
# epoch: 13 batch: 5 current batch loss: 0.13117417693138123
# epoch: 13 batch: 6 current batch loss: 0.10201160609722137
# epoch: 13 batch: 7 current batch loss: 0.11593234539031982
# epoch: 13 batch: 8 current batch loss: 0.12162111699581146
# epoch: 13 batch: 9 current batch loss: 0.11949054151773453
# epoch: 13 batch: 10 current batch loss: 0.11869321018457413
# epoch: 13 batch: 11 current batch loss: 0.12595698237419128
# epoch: 13 batch: 12 current batch loss: 0.1169218197464943
# epoch: 13 batch: 13 current batch loss: 0.10798823088407516
# epoch: 13 batch: 14 current batch loss: 0.12279391288757324
# epoch: 13 batch: 15 current batch loss: 0.10360250622034073
# epoch: 13 batch: 16 current batch loss: 0.10468695312738419
# epoch: 13 batch: 17 current batch loss: 0.14135341346263885
# epoch: 13 batch: 18 current batch loss: 0.09837478399276733
# epoch: 13 batch: 19 current batch loss: 0.10592851787805557
# epoch: 13 batch: 20 current batch loss: 0.12054521590471268
# epoch: 13 batch: 21 current batch loss: 0.10045940428972244
# epoch: 13 batch: 22 current batch loss: 0.1330992579460144
# epoch: 13 batch: 23 current batch loss: 0.1156529039144516
# epoch: 13 batch: 24 current batch loss: 0.10162349790334702
# epoch: 13 batch: 25 current batch loss: 0.10164748877286911
# epoch: 13 batch: 26 current batch loss: 0.10505802929401398
# epoch: 13 batch: 27 current batch loss: 0.12427505850791931
# epoch: 13 batch: 28 current batch loss: 0.10174677520990372
# epoch: 13 batch: 29 current batch loss: 0.12341225892305374
# epoch: 14 batch: 0 current batch loss: 0.10651181638240814
# epoch: 14 batch: 1 current batch loss: 0.11562428623437881
# epoch: 14 batch: 2 current batch loss: 0.09515195339918137
# epoch: 14 batch: 3 current batch loss: 0.12529349327087402
# epoch: 14 batch: 4 current batch loss: 0.09563036262989044
# epoch: 14 batch: 5 current batch loss: 0.113248810172081
# epoch: 14 batch: 6 current batch loss: 0.10945236682891846
# epoch: 14 batch: 7 current batch loss: 0.09943550080060959
# epoch: 14 batch: 8 current batch loss: 0.10542409867048264
# epoch: 14 batch: 9 current batch loss: 0.11052484810352325
# epoch: 14 batch: 10 current batch loss: 0.10985922813415527
# epoch: 14 batch: 11 current batch loss: 0.121752068400383
# epoch: 14 batch: 12 current batch loss: 0.10812322795391083
# epoch: 14 batch: 13 current batch loss: 0.1198512613773346
# epoch: 14 batch: 14 current batch loss: 0.09764061123132706
# epoch: 14 batch: 15 current batch loss: 0.10157353430986404
# epoch: 14 batch: 16 current batch loss: 0.09867367148399353
# epoch: 14 batch: 17 current batch loss: 0.10200119018554688
# epoch: 14 batch: 18 current batch loss: 0.10323683172464371
# epoch: 14 batch: 19 current batch loss: 0.1053343117237091
# epoch: 14 batch: 20 current batch loss: 0.0977960079908371
# epoch: 14 batch: 21 current batch loss: 0.1132940948009491
# epoch: 14 batch: 22 current batch loss: 0.11440790444612503
# epoch: 14 batch: 23 current batch loss: 0.10391964018344879
# epoch: 14 batch: 24 current batch loss: 0.09916096925735474
# epoch: 14 batch: 25 current batch loss: 0.12027664482593536
# epoch: 14 batch: 26 current batch loss: 0.08772988617420197
# epoch: 14 batch: 27 current batch loss: 0.12055066227912903
# epoch: 14 batch: 28 current batch loss: 0.1124548688530922
# epoch: 14 batch: 29 current batch loss: 0.12200784683227539
# epoch: 15 batch: 0 current batch loss: 0.11925775557756424
# epoch: 15 batch: 1 current batch loss: 0.11168520152568817
# epoch: 15 batch: 2 current batch loss: 0.1130421832203865
# epoch: 15 batch: 3 current batch loss: 0.09682643413543701
# epoch: 15 batch: 4 current batch loss: 0.10747253149747849
# epoch: 15 batch: 5 current batch loss: 0.10855726152658463
# epoch: 15 batch: 6 current batch loss: 0.10428473353385925
# epoch: 15 batch: 7 current batch loss: 0.1154666468501091
# epoch: 15 batch: 8 current batch loss: 0.10705000162124634
# epoch: 15 batch: 9 current batch loss: 0.11712244153022766
# epoch: 15 batch: 10 current batch loss: 0.08971463888883591
# epoch: 15 batch: 11 current batch loss: 0.09560934454202652
# epoch: 15 batch: 12 current batch loss: 0.10898692160844803
# epoch: 15 batch: 13 current batch loss: 0.09267359972000122
# epoch: 15 batch: 14 current batch loss: 0.1032736673951149
# epoch: 15 batch: 15 current batch loss: 0.08917901664972305
# epoch: 15 batch: 16 current batch loss: 0.08129144459962845
# epoch: 15 batch: 17 current batch loss: 0.09831494837999344
# epoch: 15 batch: 18 current batch loss: 0.08586077392101288
# epoch: 15 batch: 19 current batch loss: 0.09710896760225296
# epoch: 15 batch: 20 current batch loss: 0.0966482013463974
# epoch: 15 batch: 21 current batch loss: 0.08637800812721252
# epoch: 15 batch: 22 current batch loss: 0.10281725227832794
# epoch: 15 batch: 23 current batch loss: 0.11588780581951141
# epoch: 15 batch: 24 current batch loss: 0.09260868281126022
# epoch: 15 batch: 25 current batch loss: 0.08784818649291992
# epoch: 15 batch: 26 current batch loss: 0.10146256536245346
# epoch: 15 batch: 27 current batch loss: 0.09264222532510757
# epoch: 15 batch: 28 current batch loss: 0.0943363830447197
# epoch: 15 batch: 29 current batch loss: 0.08735392987728119

# %% [markdown]
# # Testing
# ----------------------

# %%
good = 0
wrong = 0

net.eval()              #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing evaluation
with torch.no_grad():   #it prevents that the net learns during evalution. The gradients are not computed, so this makes it faster, too
    for batch, data in enumerate(testloader): #batches in test are of size 1
        datapoint, label = data

        prediction = net(datapoint.to(device))                  #prediction has values representing the "prevalence" of the corresponding class
        classification = torch.argmax(prediction)    #the class is the index of maximal "prevalence"

        if classification.item() == label.item():
            good += 1
        else:
            wrong += 1

print("accuracy = ", good/(good+wrong))
# Out:
# accuracy =  0.978

# %% [markdown]
# # Understanding Kernel Size, Stride and Padding

# %% [markdown]
# ## Task: Designing a Convolutional Neural Network with a Target Receptive Field
#
# Design a convolutional neural network using only 3×3 or 5×5 convolutional layers and 2×2 max-pooling layers without overlap (i.e., with stride 2). Use no padding in any layer. Insert a max-pooling layer after every two or three convolutional layers.
#
# Your goal is to construct an architecture such that the receptive field of each output neuron is approximately 60×60 pixels.
#
# Compute the receptive field size of the final output layer.
#
# Compute the effective stride of the output layer with respect to the input.
#
# Assuming an input image size of 400×400, determine the spatial size of the output feature map.
#
# Q: Where would you locate ReLU layers?
# Q: What if we can't match the desired input size with our architecture?
# Q: Discuss what possible impact padding can have on the network performance.

# %% [markdown]
# # **Homework Assignment – Adversarial Examples**
#
# In this assignment, you will explore how small (invisible to humans) changes to real digits can _fool_ the CNN into misclassifying them, even though the changes are imperceptible to humans.
#
#
#
# ## Task 1 – CNN Dreams: Last Homework Assignment Revisited
#
# Re-run the input optimization process (for NN dreams) from the previous MLP-class homework assignment, but this time using the **LeNet-5 CNN model** we trained in this class.
#
#
# 1. Starting from ten random noise images, optimize the input so that each image is classified with high confidence as one of the digits 0 through 9.
# 2. Include an **L2 penalty** on the input to keep the images visually closer to realistic digits. Use a range of penalty strengths (e.g., $\lambda_{l2}$ = 0, and then 0.01 through 10.0).
# 3. Compare the generated images (with and without L2 penalty) to those generated by the MLP:
#    - Are they more or less readable?
#    - Do they resemble real MNIST digits more closely or less?
#    - Why do you think that happens? Consider the CNN’s inductive biases and architectural properties.
#
# Use `cross_entropy_loss + lambda_l2 * input.pow(2).mean()` as your objective.
#
# Reuse your code: visualize confidence evolution during optimization and generate image grids and (optionally) animations showing how the inputs evolve.
#
#
# ## Task 2 – Adversarial Examples: Fooling LeNet-5
#
# This is the core focus of the assignment.
#
# Using a batch of **real MNIST digits** (e.g., nine examples per class), craft **adversarial examples** by adding subtle, trained noise to the input images. Your goal is to:
#
# - **Keep the human-perceived digit the same** (e.g., a "7" should still look like a "7"),
# - But **cause LeNet-5 to misclassify it** – as every other class different from the original, hence nine examples per class.
#
# ### Objective
# For each image $x$ and its true label $y$, learn a perturbation $\delta$ such that:
#
# - $\text{LeNet5}(x + \delta) = y_{\text{wrong}} $,
# - and $ \|\delta\|_2 $ is as small as possible (penalize large perturbations), to keep $x + \delta$ *look* like $x$ for humans.
#
# ### Optimization
# Use gradient-based optimization on $\delta$ (the noise), while keeping the network weights frozen. Your loss might look like:
#
# ```
# loss = cross_entropy(model(x + delta), target_wrong_class) +
#        lambda_l2 * delta.pow(2).mean()
# ```
#
# Tune the $\lambda_{l2}$ to find the best range.
#
# ### Deliverables for the Second Task
# - Select some best examples, showing the original digit and its (correct) classification and the perturbed digit (hopefully, still looking the same to humans) and how it gets misclassified. Show them side by side.
# - Report:
#   - Success rate of attacks (it doesn't need to be very formal),
#   - Effect of $\lambda_{l2}$ on visibility of the noise and success of misclassification,
#   - Example image grids and confidence plots.
#
#
#
# ## Deliverables for the Homework Assignment
# - A Google Colab notebook with:
#   - Complete implementation for both tasks.
#   - Visualizations and animations (animations are optional but encouraged).
#   - Clear written analysis of your findings.
# - Upload the notebook and results to your GitHub repository for the course.
# - Include a link to the notebook and video (if applicable) in the `README.md`.
# - In the notebook, include “Open in Colab” badge so it can be launched directly.
