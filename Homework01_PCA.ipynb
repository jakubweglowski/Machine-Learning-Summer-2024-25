# %% [markdown]
# **Homework** *(PCA)*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

data = pd.read_csv("PCA_three_clusters_data.csv")
data
# Out:
#             x         y          z  class
# 0    0.647689 -0.138264   3.512299      0
# 1   -0.234137 -0.234153  10.769447      0
# 2   -0.469474  0.767435  11.166721      0
# 3   -0.465730 -0.463418   3.836479      0
# 4   -1.724918 -1.913280   1.710932      0
# ..        ...       ...        ...    ...
# 295  4.640708  0.583928  13.058193      2
# 296  5.820482  1.108704   4.176560      2
# 297  6.169296  1.066675   3.586969      2
# 298  4.832882  0.648710   9.773340      2
# 299  4.183064  1.206509   1.037422      2
#
# [300 rows x 4 columns]

# %%
X = np.array(data[['x', 'y', 'z']])
y = np.array(data['class'])
target_names = ['class_0', 'class_1', 'class_2']

# %% [markdown]
# # Data scatterplots

# %%
# 2d-scatterplot the data with color coding by class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

for i, target_name in enumerate(target_names):
    ax.scatter(X[y==i, 0], X[y==i, 1], label=target_name, alpha=0.7)

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("Scatterplot of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

plt.show()

# %%
# 2d-scatterplot the data with color coding by class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

for i, target_name in enumerate(target_names):
    ax.scatter(X[y==i, 0], X[y==i, 2], label=target_name, alpha=0.7)

ax.set_xlabel("x")
ax.set_ylabel("z")
ax.set_title("Scatterplot of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

plt.show()

# %%
# 2d-scatterplot the data with color coding by class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

for i, target_name in enumerate(target_names):
    ax.scatter(X[y==i, 1], X[y==i, 2], label=target_name, alpha=0.7)

ax.set_xlabel("y")
ax.set_ylabel("z")
ax.set_title("Scatterplot of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

plt.show()

# %% [markdown]
# # PCA

# %%
y = data['class']
target_names = ['class_0', 'class_1', 'class_2']

# Center and standardize the data before applying PCA
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Perform PCA
pca = PCA(n_components = 3)
XV = pca.fit_transform(X)

print("\nthe principal components in rows\n")
print(pca.components_)

print("\nX projected on V (first 5 rows)\n")
print(XV[:5,:])
print("\nExplained percentage variance\n")
print(pca.explained_variance_ratio_)
print("\nCumulative explained percentage variance\n")
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# the principal components in rows
#
# [[-0.72005783 -0.56946     0.39652494]
#  [-0.02368275  0.59126692  0.80612813]
#  [ 0.69350981 -0.57106806  0.43923275]]
#
# X projected on V (first 5 rows)
#
# [[ 1.12582206  0.05986874 -0.0309145 ]
#  [ 1.89368654  0.95808305  0.24333978]
#  [ 1.61886158  1.39907438 -0.17470912]
#  [ 1.61654666 -0.01318696 -0.22298896]
#  [ 2.41865284 -0.83294294 -0.20878659]]
#
# Explained percentage variance
#
# [0.34722276 0.33441835 0.31835889]
#
# Cumulative explained percentage variance
#
# [0.34722276 0.68164111 1.        ]

# %%
# 2d-plot the PCA results with color coding by class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

for i, target_name in enumerate(target_names):
    ax.scatter(XV[y==i, 0], XV[y==i, 1], label=target_name, alpha=0.7)

ax.set_xlabel("Principal Component 1")
ax.set_ylabel("Principal Component 2")
ax.set_title("PCA of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

plt.show()

# %%
# 2d-plot the PCA results with color coding by class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

for i, target_name in enumerate(target_names):
    ax.scatter(XV[y==i, 0], XV[y==i, 2], label=target_name, alpha=0.7)

ax.set_xlabel("Principal Component 1")
ax.set_ylabel("Principal Component 3")
ax.set_title("PCA of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

plt.show()

# %%
# 2d-plot the PCA results with color coding by class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

for i, target_name in enumerate(target_names):
    ax.scatter(XV[y==i, 1], XV[y==i, 2], label=target_name, alpha=0.7)

ax.set_xlabel("Principal Component 2")
ax.set_ylabel("Principal Component 3")
ax.set_title("PCA of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

plt.show()

# %%
# 3d-plot the PCA results with color coding by wine class
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(projection='3d')

for i, target_name in enumerate(target_names):
    ax.scatter(XV[y==i, 0], XV[y==i, 1], XV[y==i, 2], label=target_name, alpha=0.7)

ax.set_xlabel("Principal Component 1")
ax.set_ylabel("Principal Component 2")
ax.set_zlabel("Principal Component 3")
ax.set_title("PCA of Homework Dataset")
ax.legend(title="Class")
ax.grid(True)

ax.view_init(10, 40)

plt.show()
